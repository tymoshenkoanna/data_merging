# %% [markdown]
# <a href="https://colab.research.google.com/github/tymoshenkoanna/data_merging/blob/main/data_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

# %load_ext google.colab.data_table

url_sql='https://raw.githubusercontent.com/tymoshenkoanna/data_merging/main/sql_extract.csv'
url_val='https://raw.githubusercontent.com/tymoshenkoanna/data_merging/main/validation_report.csv'
url_tl='https://raw.githubusercontent.com/tymoshenkoanna/data_merging/main/1_tech_list.csv'

sql_file=pd.read_csv(url_sql)
sql_file = sql_file.applymap(lambda s: s.lower() if type(s) == str else s)
val_file=pd.read_csv(url_val)
val_file = val_file.applymap(lambda s: s.lower() if type(s) == str else s)
tl_file=pd.read_csv(url_tl)
tl_file = tl_file.applymap(lambda s: s.lower() if type(s) == str else s)

#PART 1
#clean-up data from the SQL file, the only data that's required from this source is: server name + installed product name and it's version

sql_file.loc[(sql_file['Product Name'] != 'mirror agent') | 
            (sql_file['Product Name'] != 'mirror scanner') |
             (sql_file['Product Name'] != 'reader nft connect'), 'new column versions'] = sql_file['Product Version'].astype(str).str[:3]
sql_file.loc[(sql_file['Product Name'] == 'mirror agent') | 
            (sql_file['Product Name'] == 'mirror scanner'), 'new column versions'] = sql_file['Product Version'].astype(str).str[:4]
sql_file.loc[(sql_file['Product Name'] == 'gbc'), 'new column versions'] = sql_file['Product Version'].astype(str).str[:5]
sql_file.loc[(sql_file['Product Version'] == 'NOTKNOWN'), 'new column versions'] = 'nan'
sql_file.loc[(sql_file['Product Name'] == 'reader box'), 'Product Name'] = 'reader'
sql_file.loc[(sql_file['Product Name'] == 'reader tracker'), 'Product Name'] = 'tracker'

sql_file['Product Name'] = sql_file['Product Name'] + ' ' + sql_file['new column versions']

sql_df=sql_file[["Product Name", "Server Name"]]
#print(sql_df)

#PART 2
#clean-up data from the technology list, the only data that's required form the source is: product name + product version + Product ID; merge the output with sql_df

tl_df=tl_file[["Product Name", "Product ID"]]
print(tl_df)


#merge two dataframes, tl_df and sql_df, left merging to make sure all entries are in the outcome, including ones that miss the match
sql_tl_df = pd.merge(left=sql_df, right=tl_df, how='left', left_on='Product Name', right_on='Product Name')
print(sql_tl_df)

#PART 3
#clean-up all the data from the validation list, only data that's required is server name + Product ID; merge the output with sql_tl_df
val_df=val_file[["Server Name", "Product ID"]]
print(val_df)


#continue here !!!!
#sql_tl_dict = dict(zip(sql_tl_df['Product name'], sql_tl_df['Server Name'], sql_tl_df['Product ID']))



# %unload_ext google.colab.data_table
# Out:
#              Product Name Product ID
# 0              reader 4.8   idtf2430
# 1              reader 1.3   idtf1375
# 2           reader 1.3.19   idtf1376
# 3              reader 3.2   idtf1377
# 4              reader 4.6   idtf1382
# 5   reader fancy software  idtf25436
# 6         reader measurer  idtf25772
# 7              reader pdf  idtf25805
# 8       reader subversion  idtf27461
# 9             tracker 6.7   idtf6354
# 10            tracker 7.9   idtf6354
# 11             reader new  idtf27565
# 12             reader poi  idtf31165
# 13                 reader   idtf9086
# 14            tracker 7.9   idtf1433
# 15            tracker 9.7   idtf1424
# 16              tracker 5   idtf1425
# 17            tracker 6.5   idtf1428
# 18            tracker 7.6   idtf1429
# 19            tracker 8.0  idtf26616
# 20            tracker 8.5  idtf29394
# 21             tracker 10  idtf30816
# 22             tracker 12   idt16871
# 23              apc agent   idt88769
# 24      mirror agent 14.6   idtf0023
# 25    mirror agent 13.6.8   idtf0089
# 26       mirror agent 9.6   idtf1402
# 27              gbc 7.6.4   idtf6655
# 28              gbc 7.6.8   idtf6657
# 29    mirror agent 10.2.0  idtf17449
# 30    mirror agent 14.7.7  idtf17450
# 31         mirror agent 9  idtf17489
# 32     mirror agent 16.81   idtf1787
# 33   mirror agent 110.5.6   idtf1789
# 34  mirror scanner 14.7.6   idtf1853
# 35  mirror scanner 12.4.6  idtf18534
# 36    mirror scanner 12.1  idtf28724
# 37  mirror scanner 14.0.1  idtf30999
# 38    mirror scanner 11.5  idtf35764
#                        Product Name                    Server Name Product ID
# 0                        reader 4.8   wrfdrpractd56.jdgf.uh.ok.org   idtf2430
# 1            reader nft connect 4.5   wrfdrpractd56.jdgf.uh.ok.org        NaN
# 2                       tracker 7.9    wrfdgbcs0001.jdgf.uh.ok.org   idtf6354
# 3                       tracker 7.9    wrfdgbcs0001.jdgf.uh.ok.org   idtf1433
# 4                        reader 9.6     wrfdrerfd11.jdgf.uh.ok.org        NaN
# 5               mirror scanner 11.5   wrfdrpractd56.jdgf.uh.ok.org  idtf35764
# 6                  mirror agent nan  wrfdreccsfro01.jdgf.uh.ok.org        NaN
# 7       mirror-agent 12c 32-bit nan     lotrwif002wrfd66.uh.ok.org        NaN
# 8         mirror agent 11.2.0.3 nan       geodbapcui8981.ki.gb.org        NaN
# 9   mirror recovery controltool 5.6       wrfdpcas4.jdgf.uh.ok.org        NaN
# 10             reader basic trc 4.9      geotcpaplui8981.ki.gb.org        NaN
# 11                         po98 5.3    wrfdphrsap02.jdgf.uh.ok.org        NaN
# 12                     rd agent 3.5     lotrwbc071wrfd66.uh.ok.org        NaN
# 13                        gbc 7.6.8   wrfdrpractd25.jdgf.uh.ok.org   idtf6657
# 14            diffusion make k9 4.0  wrfdptkacwas06.jdgf.uh.ok.org        NaN
# 15                     rd agent 3.5     lotrwbc063wrfd66.uh.ok.org        NaN
# 16                          nbi not     lotrwrt072wrfd86.uh.ok.org        NaN
# 17                     rdseries 768       anb6785.thd.hgd.okij.org        NaN
# 18        arriga pressure count 4.5       wrfdrmbm4.jdgf.uh.ok.org        NaN
# 19                    apc agent nan       geoidsftpp0001.ki.gb.org        NaN
#                       Server Name Product ID
# 0    wrfdrpractd56.jdgf.uh.ok.org   idtf1382
# 1    wrfdrpractd56.jdgf.uh.ok.org   idtf1382
# 2    wrfdrpractd56.jdgf.uh.ok.org   idtf1382
# 3    wrfdrpractd56.jdgf.uh.ok.org   idtf1382
# 4    wrfdrpractd78.jdgf.uh.ok.org   idtf1382
# 5    wrfdrpractd56.jdgf.uh.ok.org   idtf1382
# 6    wrfdrpractd78.jdgf.uh.ok.org   idtf1382
# 7    wrfdrpractd56.jdgf.uh.ok.org   idtf2430
# 8         wrdfhr43.jdgf.uh.ok.org   idtf2430
# 9      wrdfhsatc43.jdgf.uh.ok.org   idtf2430
# 10     wrdfhsatc32.jdgf.uh.ok.org   idtf2430
# 11       wrwjdlt08.jdgf.uh.ok.org   idtf2430
# 12     wrdfhsatc43.jdgf.uh.ok.org   idtf2430
# 13     wrdfhsatc32.jdgf.uh.ok.org   idtf2430
# 14       wrwjdlt08.jdgf.uh.ok.org   idtf2430
# 15   wrfdrpractd56.jdgf.uh.ok.org   idtf1838
# 16   wrfdrpractd78.jdgf.uh.ok.org   idtf1838
# 17   wrfdrpractd56.jdgf.uh.ok.org   idtf1838
# 18   wrfdrpractd78.jdgf.uh.ok.org   idtf1838
# 19   wrfdrpractd56.jdgf.uh.ok.org   idtf1838
# 20   wrfdrpractd78.jdgf.uh.ok.org   idtf1838
# 21      wdohfpkomapb456.lb.ok.com   idtf1419
# 22      wdohfpkomapp456.lb.ok.com   idtf1419
# 23      wdohfpkomapb456.lb.ok.com   idtf1419
# 24      wdohfpkomapp456.lb.ok.com   idtf1419
# 25      wdohfpkomapb456.lb.ok.com   idtf1419
# 26      wdohfpkomapp456.lb.ok.com   idtf1419
# 27      wdohfpkomapb456.lb.ok.com   idtf1419
# 28      wdohfpkomapp456.lb.ok.com   idtf1419
# 29       wrdgfymt2.jdgf.uh.ok.org   idtf1839
# 30       wrdgfymt2.jdgf.uh.ok.org   idtf1839
# 31       wrdgfymt2.jdgf.uh.ok.org   idtf1839
# 32      wrdgwdde01.jdgf.uh.ok.org   idtf1433
# 33      wafdpt24db.jdgf.uh.ok.org   idtf1430
# 34     wrdfhpt32db.jdgf.uh.ok.org   idtf1430
# 35    wrfdgbcs0001.jdgf.uh.ok.org   idtf1433
# 36    wrfdgbcs0001.jdgf.uh.ok.org   idtf1433
# 37    wrfdgbcs0001.jdgf.uh.ok.org   idtf1433
# 38    wrfdgbcs0001.jdgf.uh.ok.org   idtf1433
# 39   wrfdrpractd56.jdgf.uh.ok.org   idtf1853
# 40   wrfdrpractd78.jdgf.uh.ok.org   idtf1853
# 41   wrfdrpractd56.jdgf.uh.ok.org   idtf1853
# 42   wrfdrpractd78.jdgf.uh.ok.org   idtf1853
# 43  wrfdreccsfro01.jdgf.uh.ok.org   idtf1853
# 44      diirpmu012waf86.uh.db.com   idtf1853
# 45  wrfdreccsfro01.jdgf.uh.ok.org   idtf1853
# 46      diirwho432waf86.uh.db.com   idtf1853
